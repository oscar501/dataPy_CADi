# %%
# Import required libraries
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import baseballAux as aux
# %matplotlib inline

# %%
# Defining data sources types
DATA_TYPES_SOURCE = '../data/extracted/baseball/keysDict.pickle'
DATA_PATH = "../data/extracted/baseball/game_logs.csv"

# %%
# Loading the data types as defined in the previous exercise
with open(DATA_TYPES_SOURCE, 'rb') as handle:
    dataTypes = pickle.load(handle)
print(dataTypes)
# Out:
# {'number_of_game': 'int64', 'day_of_week': 'category', 'v_name': 'category', 'v_league': 'category', 'v_game_number': 'int64', 'h_name': 'category', 'h_league': 'category', 'h_game_number': 'int64', 'v_score': 'int64', 'h_score': 'int64', 'length_outs': 'float32', 'day_night': 'category', 'completion': 'category', 'forefeit': 'category', 'protest': 'category', 'park_id': 'category', 'attendance': 'float32', 'length_minutes': 'float32', 'v_line_score': 'category', 'h_line_score': 'category', 'v_at_bats': 'float32', 'v_hits': 'float32', 'v_doubles': 'float32', 'v_triples': 'float32', 'v_homeruns': 'float32', 'v_rbi': 'float32', 'v_sacrifice_hits': 'float32', 'v_sacrifice_flies': 'float32', 'v_hit_by_pitch': 'float32', 'v_walks': 'float32', 'v_intentional walks': 'float32', 'v_strikeouts': 'float32', 'v_stolen_bases': 'float32', 'v_caught_stealing': 'float32', 'v_grounded_into_double': 'float32', 'v_first_catcher_interference': 'float32', 'v_left_on_base': 'float32', 'v_pitchers_used': 'float32', 'v_individual_earned_runs': 'float32', 'v_team_earned_runs': 'float32', 'v_wild_pitches': 'float32', 'v_balks': 'float32', 'v_putouts': 'float32', 'v_assists': 'float32', 'v_errors': 'float32', 'v_passed_balls': 'float32', 'v_double_plays': 'float32', 'v_triple_plays': 'float32', 'h_at_bats': 'float32', 'h_hits': 'float32', 'h_doubles': 'float32', 'h_triples': 'float32', 'h_homeruns': 'float32', 'h_rbi': 'float32', 'h_sacrifice_hits': 'float32', 'h_sacrifice_flies': 'float32', 'h_hit_by_pitch': 'float32', 'h_walks': 'float32', 'h_intentional walks': 'float32', 'h_strikeouts': 'float32', 'h_stolen_bases': 'float32', 'h_caught_stealing': 'float32', 'h_grounded_into_double': 'float32', 'h_first_catcher_interference': 'float32', 'h_left_on_base': 'float32', 'h_pitchers_used': 'float32', 'h_individual_earned_runs': 'float32', 'h_team_earned_runs': 'float32', 'h_wild_pitches': 'float32', 'h_balks': 'float32', 'h_putouts': 'float32', 'h_assists': 'float32', 'h_errors': 'float32', 'h_passed_balls': 'float32', 'h_double_plays': 'float32', 'h_triple_plays': 'float32', 'hp_umpire_id': 'category', 'hp_umpire_name': 'category', '1b_umpire_id': 'category', '1b_umpire_name': 'category', '2b_umpire_id': 'category', '2b_umpire_name': 'category', '3b_umpire_id': 'category', '3b_umpire_name': 'category', 'lf_umpire_id': 'category', 'lf_umpire_name': 'category', 'rf_umpire_id': 'category', 'rf_umpire_name': 'category', 'v_manager_id': 'category', 'v_manager_name': 'category', 'h_manager_id': 'category', 'h_manager_name': 'category', 'winning_pitcher_id': 'category', 'winning_pitcher_name': 'category', 'losing_pitcher_id': 'category', 'losing_pitcher_name': 'category', 'saving_pitcher_id': 'category', 'saving_pitcher_name': 'category', 'winning_rbi_batter_id': 'category', 'winning_rbi_batter_id_name': 'category', 'v_starting_pitcher_id': 'category', 'v_starting_pitcher_name': 'category', 'h_starting_pitcher_id': 'category', 'h_starting_pitcher_name': 'category', 'v_player_1_id': 'category', 'v_player_1_name': 'category', 'v_player_1_def_pos': 'float32', 'v_player_2_id': 'category', 'v_player_2_name': 'category', 'v_player_2_def_pos': 'float32', 'v_player_3_id': 'category', 'v_player_3_name': 'category', 'v_player_3_def_pos': 'float32', 'v_player_4_id': 'category', 'v_player_4_name': 'category', 'v_player_4_def_pos': 'float32', 'v_player_5_id': 'category', 'v_player_5_name': 'category', 'v_player_5_def_pos': 'float32', 'v_player_6_id': 'category', 'v_player_6_name': 'category', 'v_player_6_def_pos': 'float32', 'v_player_7_id': 'category', 'v_player_7_name': 'category', 'v_player_7_def_pos': 'float32', 'v_player_8_id': 'category', 'v_player_8_name': 'category', 'v_player_8_def_pos': 'float32', 'v_player_9_id': 'category', 'v_player_9_name': 'category', 'v_player_9_def_pos': 'float32', 'h_player_1_id': 'category', 'h_player_1_name': 'category', 'h_player_1_def_pos': 'float32', 'h_player_2_id': 'category', 'h_player_2_name': 'category', 'h_player_2_def_pos': 'fl ...

# %%
# Loading the dataset and doing the data optimization "on the fly"
optimized_gl = pd.read_csv(
    DATA_PATH,
    dtype=dataTypes,
    parse_dates=['date'],
    infer_datetime_format=True,
    low_memory=False
)
print(aux.mem_usage(optimized_gl))
# Out:
# 110.02 MB

# %%
# Doing some plots on the ratio of games per day
optimized_gl['year'] = optimized_gl.date.dt.year
games_per_day = optimized_gl.pivot_table(
    index='year', columns='day_of_week',
    values='date', aggfunc=len
)
games_per_day = games_per_day.divide(games_per_day.sum(axis=1), axis=0)
ax = games_per_day.plot(kind='area', stacked='true')
ax.legend(loc='upper right')
ax.set_ylim(0, 1)
plt.show()
#plt.close()

# %%
# Loading the dataset by chunks
optimized_gl = pd.read_csv(
    DATA_PATH,
    dtype=dataTypes,
    parse_dates=['date'],
    infer_datetime_format=True,
    low_memory=False,
    chunksize=10000
)
df = pd.DataFrame()
for gm_chunk in optimized_gl:
    df = pd.concat([df, gm_chunk])
    print(len(gm_chunk))
df.head()
# Out:
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 1907
#         date  number_of_game day_of_week v_name v_league  v_game_number  \
# 0 1871-05-04               0         Thu    CL1       na              1
# 1 1871-05-05               0         Fri    BS1       na              1
# 2 1871-05-06               0         Sat    CL1       na              2
# 3 1871-05-08               0         Mon    CL1       na              3
# 4 1871-05-09               0         Tue    BS1       na              2
#
#   h_name h_league  h_game_number  v_score  ...  h_player_7_name  \
# 0    FW1       na              1        0  ...       Ed Mincher
# 1    WS3       na              1       20  ...     Asa Brainard
# 2    RC1       na              1       12  ...       Pony Sager
# 3    CH1       na              1       12  ...         Ed Duffy
# 4    TRO       na              1        9  ...     Steve Bellan
#
#    h_player_7_def_pos h_player_8_id  h_player_8_name h_player_8_def_pos  \
# 0                 7.0      mcdej101  James McDermott                8.0
# 1                 1.0      burrh101  Henry Burroughs                9.0
# 2                 6.0      birdg101      George Bird                7.0
# 3                 6.0      pinke101       Ed Pinkham                5.0
# 4                 5.0      pikel101         Lip Pike                3.0
#
#   h_player_9_id  h_player_9_name  h_player_9_def_pos  additional_info  \
# 0      kellb105       Bill Kelly                 9.0              NaN
# 1      berth101  Henry Berthrong                 8.0             HTBF
# 2      stirg101       Gat Stires                 9.0              NaN
# 3      zettg101  George Zettlein                 1.0              NaN
# 4      cravb101      Bill Craver                 6.0             HTBF
#
#   acquisition_info
# 0                Y
# 1                Y
# 2                Y
# 3                Y
# 4                Y
#
# [5 rows x 161 columns]

# %%
# Follow up: filter the loaded dataset to contain only: date and day of
#   the week and export to a CSV file
#   (http://acepor.github.io/2017/08/03/using-chunksize/)
