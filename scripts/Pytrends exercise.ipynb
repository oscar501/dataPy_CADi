# %%
import pickle
import pandas as pd
from pytrends.request import TrendReq
from matplotlib import rcParams
# %matplotlib inline
rcParams.update({'figure.autolayout': True})

# %%
kw_list = ["biosensor"]
pytrends = TrendReq(hl='en-US', tz=360)
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='', gprop='')

# %%
interest_over_time_df = pytrends.interest_over_time()

# %%
dataDumpPath = "../data/extracted/Trends/dataDump.pkl"
interest_over_time_df.to_pickle(dataDumpPath)
interest_over_time_df = pd.read_pickle(dataDumpPath)
# interest_over_time_df.loc['2017-10-26']
print(interest_over_time_df.head())
interest_over_time_df["biosensor"].plot()
# Out:
#             biosensor isPartial
# date
# 2014-06-15         60     False
# 2014-06-22         60     False
# 2014-06-29         63     False
# 2014-07-06         53     False
# 2014-07-13         55     False

# %%
# Interest by Region
interest_by_region_df = pytrends.interest_by_region()
interest_by_region_df.sort_values(
    by=["biosensor"], ascending=False, inplace=True
)
interest_by_region_df.iloc[:20].plot.bar()
# fig = interest_by_region_df.iloc[:20].plot.bar()
# fig.get_figure().savefig('trends.png',dpi=500)

# %%
# Related Queries, returns a dictionary of dataframes
related_queries_dict = pytrends.related_queries()
print(related_queries_dict)
# Out:
# {'biosensor': {'top':                               query  value
# 0                            sensor    100
# 1                        biosensors    100
# 2                 biosensor glucose     98
# 3         electrochemical biosensor     70
# 4                 what is biosensor     41
# 5                 optical biosensor     38
# 6                graphene biosensor     37
# 7                      sd biosensor     35
# 8              biosensor technology     33
# 9          application of biosensor     28
# 10           amperometric biosensor     25
# 11                    biosensor ppt     24
# 12     biosensor and bioelectronics     22
# 13               wearable biosensor     19
# 14                              spr     17
# 15        surface plasmon resonance     17
# 16        glucose oxidase biosensor     15
# 17             biosensor definition     14
# 18                   google scholar     13
# 19                  strip biosensor      9
# 20                   biosensor 2016      8
# 21                biosensor lactate      7
# 22                          analyte      6
# 23          biosensor equipment llc      6
# 24  sd biosensor healthcare pvt ltd      4, 'rising':                                                 query  value
# 0                                      biosensor 2016  43650
# 1                             biosensor equipment llc  30750
# 2                                 biosensor glutamine   9450
# 3   an rna biosensor for imaging the first round o...   9300
# 4                     sd biosensor healthcare pvt ltd    400
# 5                                    biosensor tattoo    350
# 6                        biosensor is used to measure    350
# 7                                      google scholar    300
# 8                                        sd biosensor    300
# 9                                     strip biosensor    250
# 10                                 wearable biosensor    250
# 11                                  biosensor lactate    110
# 12                                            analyte    110
# 13                                 graphene biosensor    100
# 14                                  what is biosensor     80
# 15                               biosensor definition     40
# 16                          electrochemical biosensor     40}}

# %%
suggestions_dict = pytrends.suggestions(keyword='pizza')
print(suggestions_dict)
# Out:
# [{'mid': '/m/0663v', 'title': 'Pizza', 'type': 'Dish'}, {'mid': '/m/03clwm', 'title': "Domino's Pizza", 'type': 'Restaurant company'}, {'mid': '/m/09cfq', 'title': 'Pizza Hut', 'type': 'Restaurant company'}, {'mid': '/m/020tvm', 'title': "Papa John's Pizza", 'type': 'Restaurant company'}, {'mid': '/m/02618z5', 'title': 'Pizza 73', 'type': 'Restaurant company'}]

# %%
# Get Google Hot Trends data
trending_searches_df = pytrends.trending_searches()
print(trending_searches_df.head())
# Out:
#                        0
# 0  Australia vs Pakistan
# 1           Maren Morris
# 2            Nintendo E3
# 3            Jon Stewart
# 4          Banjo-Kazooie

# %%
# Get Google Top Charts
top_charts_df = pytrends.top_charts(cid='actors', date=201611)
print(top_charts_df.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0799248eba9d> in <module>
#       1 # Get Google Top Charts
# ----> 2 top_charts_df = pytrends.top_charts(cid='actors', date=201611)
#       3 print(top_charts_df.head())
#
# TypeError: top_charts() got an unexpected keyword argument 'cid'
